# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

ShaclSimpleNotOpt = 'SHACL Simple Not Opt.'
ShaclSimpleOpt = 'SHACL Simple Opt.'
ShaclComplexNotOpt = 'SHACL Complex Not Opt.'
ShaclComplexOpt = 'SHACL Complex Opt.'
NoshaclSimple = 'No SHACL Simple'
NoshaclComplex = 'No SHACL Complex'
ScSimple = 'SC Simple'
ScComplex = 'SC Complex'

ColorShaclSimpleNotOpt = '#92C5F9'
ColorShaclSimpleOpt = ColorShaclSimpleNotOpt

ColorShaclComplexNotOpt = '#4394E5'
ColorShaclComplexOpt = ColorShaclComplexNotOpt

ColorNoshaclSimple = '#AFDC8F'
ColorNoshaclComplex = '#87BB62' 

ColorScSimple = '#F8AE54'
ColorScComplex = '#F5921B'



x_labels = ['CREATE', 'ADV', 'BUYOFFER', 'SELL', 'REQUEST_RETURN', 'RETURN']  # Transaction types

# Data shacl simple not opt : 7
set1_min = [701, 529, 3190, 4188, 29313, 8870]  # Set 1: min values
set1_max = [2920, 16014, 18699, 30379, 41804, 67701]  # Set 1: max values
set1_avg = [1989.01,13358.14, 14547.84,19344.18,38589.4, 52413.13]  # Set 1: average values

#shacl simple opt: 3
set2_min = [630,5994,752,4691,27315,17126]  # Set 2: min values
set2_max = [3472,12464,11927,45813,33269,40978]  # Set 2: max values
set2_avg = [2391.47,9671.77,9442.35,31091.13,30209.89,33648.61]  # Set 2: average values

#non shacl simple 11
set3_min = [456,960,1776,1196,1062,1475]  # Set 2: min values
set3_max = [3550,8316,3319,3421,2196,2424]  # Set 2: max values
set3_avg = [1432.29,5485.28,2882.27,2868.81,1797.77,2060.48]  # Set 3: average values

# sc
set4_min = [4306, 4306,4304,4306,4306,4305]  # Set 4: min values 
set4_max = [7396, 5405,  5350, 5362,5345, 5368]  # Set 4: max values
set4_avg = [4849.830000, 4858.845794,4842.873832 , 4843.520000 ,4877.146667,4810.766667 ]  # Set 4: average values

# Create a DataFrame for data
data = {
    'set1_min': set1_min,
    'set1_max': set1_max,
    'set1_avg': set1_avg,
    'set2_min': set2_min,
    'set2_max': set2_max,
    'set2_avg': set2_avg,
    'set3_min': set3_min,
    'set3_max': set3_max,
    'set3_avg': set3_avg,
    'set4_min': set4_min,
    'set4_max': set4_max,
    'set4_avg': set4_avg,
}
df = pd.DataFrame(data, index=x_labels)

# Create a figure for the bar chart
fig, ax = plt.subplots(figsize=(14, 8))

# Bar width and positions
bar_width = 0.2
index = np.arange(len(x_labels))
colors = ['#377eb8', '#4daf4a', '#e41a1c', '#984ea3', '#ff7f00', '#A52A2A', '#a65628', '#f781bf']
hatches = ['|', 'x', '\\', '..', '-', '', '|', '/']  # Crosshatch every second bar
capabilities = [ShaclSimpleNotOpt, ShaclSimpleOpt, ShaclComplexNotOpt, 
                ShaclComplexOpt, NoshaclSimple,NoshaclComplex,  ScSimple, ScComplex]

# Bar chart for each set with error bars
bars = []
bars.append(ax.bar(index - 1.5 * bar_width, df['set1_avg'], bar_width, color=ColorShaclSimpleNotOpt,
                   yerr=[df['set1_avg'] - df['set1_min'], df['set1_max'] - df['set1_avg']], capsize=5, edgecolor='black'))

bars.append(ax.bar(index - 0.5 * bar_width, df['set2_avg'], bar_width, hatch=hatches[1], color=ColorShaclSimpleOpt,
                   yerr=[df['set2_avg'] - df['set2_min'], df['set2_max'] - df['set2_avg']], capsize=5, edgecolor='black'))

bars.append(ax.bar(index + 0.5 * bar_width, df['set3_avg'], bar_width, color=ColorNoshaclSimple,
                   yerr=[df['set3_avg'] - df['set3_min'], df['set3_max'] - df['set3_avg']], capsize=5, edgecolor='black'))

bars.append(ax.bar(index + 1.5 * bar_width, df['set4_avg'], bar_width, color=ColorScSimple,
                   yerr=[df['set4_avg'] - df['set4_min'], df['set4_max'] - df['set4_avg']], capsize=5, edgecolor='black'))

# Set labels and title
ax.set_title('Average Latency Simple Validation', fontsize=16,fontweight='bold')
ax.set_xlabel('Transaction Type', fontsize=16, fontweight='bold')
ax.set_ylabel('Latency (ms, log scale)', fontsize=16,fontweight='bold')

# Log scale for the y-axis to accommodate disparity
ax.set_yscale('log')

# Adjust x-tick positions and labels
ax.set_xticks(index)
ax.set_xticklabels(x_labels, fontsize=14,fontweight='bold')

ax.legend([bars[0], bars[1], bars[2], bars[3]],
          [ShaclSimpleNotOpt, ShaclSimpleOpt, NoshaclSimple, ScSimple],
          fontsize=12, loc='upper left')

# Layout adjustment for better spacing
plt.tight_layout()

plt.savefig("chart1.pdf", format='pdf')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Data shacl simple not opt : 8
x_labels = ['CREATE', 'ADV', 'BUYOFFER', 'SELL', 'REQUEST_RETURN', 'RETURN']  # Transaction types
set1_min = [460, 25457,12397,31631,106211,154115]  # Set 1: min values
set1_max = [20255,111719,120097,265985,204394,339346]  # Set 1: max values
set1_avg = [14669.12,92633.77,83667.2,195431.49,155652.42,302121.94]  # Set 1: average values
#shacl simple opt: 4
set2_min = [453,462,3083,3478,27174,8719]  # Set 2: min values
set2_max = [9885,37034,71019,167015,158897,226789]  # Set 2: max values
set2_avg = [5173.91,27633.33,39414.27,99339.3,97047.94,155034.21]  # Set 2: average values
#non shacl simple 12
set3_min = [707,18404,28610,3903,415,3791]  # Set 2: min values
set3_max = [12100,36133,52983,83633,28465,32301]  # Set 2: max values
set3_avg = [6819.76,24890.21,41097.85,44938.04,14113.66,21242.25]  # Set 3: average values
# sc
set4_min = [4302, 4302,4301,4301,4302,4301]  # Set 4: min values 
set4_max = [5448, 5448,  5357, 5354,5387, 5332]  # Set 4: max values
set4_avg = [4842.485981,4842.485981 , 4839.108645 ,4837.903333   , 4843.520000 , 4854.890000  ]  # Set 4: average values
 
# Create a DataFrame for data
data = {
    'set1_min': set1_min,
    'set1_max': set1_max,
    'set1_avg': set1_avg,
    'set2_min': set2_min,
    'set2_max': set2_max,
    'set2_avg': set2_avg,
    'set3_min': set3_min,
    'set3_max': set3_max,
    'set3_avg': set3_avg,
    'set4_min': set4_min,
    'set4_max': set4_max,
    'set4_avg': set4_avg,
}
df = pd.DataFrame(data, index=x_labels)

# Create a figure for the bar chart
fig, ax = plt.subplots(figsize=(14, 8))

# Bar width and positions
bar_width = 0.2
index = np.arange(len(x_labels))

index = np.arange(len(x_labels))
colors = ['#377eb8', '#4daf4a', '#e41a1c', '#984ea3', '#ff7f00', '#A52A2A', '#a65628', '#f781bf']
hatches = ['|', 'x', '\\', '..', '-', '', '|', '/']  # Crosshatch every second bar
capabilities = ['ShaclSimpleNotOpt', 'ShaclSimpleOpt', 'ShaclComplexNotOpt', 
                'ShaclComplexOpt', 'NoshaclSimple','NoshaclComplex',  'ScSimple', 'ScComplex']

# Bar chart for each set with error bars
bars = []
bars.append(ax.bar(index - 1.5 * bar_width, df['set1_avg'], bar_width, color=ColorShaclSimpleNotOpt,
                   yerr=[df['set1_avg'] - df['set1_min'], df['set1_max'] - df['set1_avg']], capsize=5, edgecolor='black'))

bars.append(ax.bar(index - 0.5 * bar_width, df['set2_avg'], bar_width, hatch=hatches[1], color=ColorShaclSimpleOpt,
                   yerr=[df['set2_avg'] - df['set2_min'], df['set2_max'] - df['set2_avg']], capsize=5, edgecolor='black'))

bars.append(ax.bar(index + 0.5 * bar_width, df['set3_avg'], bar_width, color=ColorNoshaclSimple,
                   yerr=[df['set3_avg'] - df['set3_min'], df['set3_max'] - df['set3_avg']], capsize=5, edgecolor='black'))

bars.append(ax.bar(index + 1.5 * bar_width, df['set4_avg'], bar_width, color=ColorScSimple,
                   yerr=[df['set4_avg'] - df['set4_min'], df['set4_max'] - df['set4_avg']], capsize=5, edgecolor='black'))

# Set labels and title
ax.set_title('Average Latency Simple Validation', fontsize=16,fontweight='bold')
ax.set_xlabel('Transaction Type', fontsize=16, fontweight='bold')
ax.set_ylabel('Latency (ms, log scale)', fontsize=16,fontweight='bold')

# Log scale for the y-axis to accommodate disparity
ax.set_yscale('log')

# Adjust x-tick positions and labels
ax.set_xticks(index)
ax.set_xticklabels(x_labels, fontsize=14,fontweight='bold')
#ax.legend(fontsize=10)

ax.legend([bars[0], bars[1], bars[2], bars[3]],
          [ShaclSimpleNotOpt, ShaclSimpleOpt, NoshaclSimple, ScSimple],
          fontsize=12, loc='upper left')

# Layout adjustment for better spacing
plt.tight_layout()

plt.savefig("chart2.pdf", format='pdf')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#shacl complex 1P

#shacl complex not opt: 5
set1_min = [515,723,2620,3430,28346,19635]  # Set 2: min values
set1_max = [2642,10904,15558,32196,37735,33443]  # Set 2: max values
set1_avg = [1263.85,9044.85,11605,19679.86,35147.47,30246.88]  # Set 2: average values

# Data shacl complex  opt : 1
x_labels = ['CREATE', 'ADV', 'BUYOFFER', 'SELL', 'REQUEST_RETURN', 'RETURN']  # Transaction types
set2_min = [453,6203,3128,3781,33501,8349]  # Set 1: min values
set2_max = [3009,14114,12383,47602,40399,45482]  # Set 1: max values
set2_avg = [1812.16,10205.46,9349.65,29385.53,37782.11,26245.58]  # Set 1: average values

#non shacl complex 9
set3_min = [338,677,4665,4328,2856,5789]  # Set 2: min values
set3_max = [5912,8576,9515,11035,10701,5893]  # Set 2: max values
set3_avg = [4423.4,6912.33,8148.01,10591.06,9495.55,5856.33]  # Set 3: average values

# sc
set4_min = [4305, 4305,4305,4306,4305,4305]  # Set 4: min values 
set4_max = [5349, 5370,  5376, 5368,5399, 5392]  # Set 4: max values
set4_avg = [4835.001667 , 4858.845794,4842.149533  , 4840.170000 , 4846.543333 ,4827.030000 ]  # Set 4: average values
 
# Create a DataFrame for data
data = {
    'set1_min': set1_min,
    'set1_max': set1_max,
    'set1_avg': set1_avg,
    'set2_min': set2_min,
    'set2_max': set2_max,
    'set2_avg': set2_avg,
    'set3_min': set3_min,
    'set3_max': set3_max,
    'set3_avg': set3_avg,
    'set4_min': set4_min,
    'set4_max': set4_max,
    'set4_avg': set4_avg,
}
df = pd.DataFrame(data, index=x_labels)

# Create a figure for the bar chart
fig, ax = plt.subplots(figsize=(14, 8))

# Bar width and positions 1P
bar_width = 0.2
index = np.arange(len(x_labels))
colors = ['#377eb8', '#4daf4a', '#e41a1c', '#984ea3', '#ff7f00', '#A52A2A', '#a65628', '#f781bf']
hatches = ['|', 'x', '\\', '..', '-', '', '|', '/']  # Crosshatch every second bar
capabilities = ['ShaclSimpleNotOpt', 'ShaclSimpleOpt', 'ShaclComplexNotOpt', 
                'ShaclComplexOpt', 'NoshaclSimple','NoshaclComplex',  'ScSimple', 'ScComplex']
# Bar chart for each set with error bars
bars = [
       ax.bar(index - 1.5 * bar_width, df['set1_avg'], bar_width, color=ColorShaclComplexNotOpt,
              yerr=[df['set1_avg'] - df['set1_min'], df['set1_max'] - df['set1_avg']], capsize=5, edgecolor='black'),

       ax.bar(index - 0.5 * bar_width, df['set2_avg'], bar_width, color=ColorShaclComplexOpt, hatch= hatches[1],
              yerr=[df['set2_avg'] - df['set2_min'], df['set2_max'] - df['set2_avg']], capsize=5, edgecolor='black'),

       ax.bar(index + 0.5 * bar_width, df['set3_avg'], bar_width, color=ColorNoshaclComplex,
              yerr=[df['set3_avg'] - df['set3_min'], df['set3_max'] - df['set3_avg']], capsize=5, edgecolor='black'),

       ax.bar(index + 1.5 * bar_width, df['set4_avg'], bar_width, color=ColorScComplex,
              yerr=[df['set4_avg'] - df['set4_min'], df['set4_max'] - df['set4_avg']], capsize=5, edgecolor='black')
]

# Set labels and title
ax.set_title('Average Latency Complex Validation', fontsize=16,fontweight='bold')
ax.set_xlabel('Transaction Type', fontsize=16, fontweight='bold')
ax.set_ylabel('Latency (ms, log scale)', fontsize=16,fontweight='bold')

# Log scale for the y-axis to accommodate disparity
ax.set_yscale('log')

# Adjust x-tick positions and labels
ax.set_xticks(index)
ax.set_xticklabels(x_labels, fontsize=14,fontweight='bold')
#ax.legend(fontsize=10)

ax.legend([bars[0], bars[1], bars[2], bars[3]],
          [ShaclComplexNotOpt, ShaclComplexOpt, NoshaclComplex, ScComplex],
          fontsize=12, loc='upper left')

# Layout adjustment for better spacing
plt.tight_layout()

plt.savefig("chart3.pdf", format='pdf')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#shacl complex 4P
# Data shacl complex not opt : 6
x_labels = ['CREATE', 'ADV', 'BUYOFFER', 'SELL', 'REQUEST_RETURN', 'RETURN']  # Transaction types
set1_min = [457,5482,3215,3945,28815,9604]  # Set 1: min values
set1_max = [13823,63517,73423,119162,163817,134316]  # Set 1: max values
set1_avg = [7743.84,48432.63,40743.71,73227.05,126269.32,93674.11]  # Set 1: average values
#shacl complex opt: 2
set2_min = [590,30372,59270,52915,188903,180101]  # Set 2: min values
set2_max = [23025,458785,298931,320974,249487,295326]  # Set 2: max values
set2_avg = [12964.6,249326.04,212886.96,227703.11,227909.76,266514.82]  # Set 2: average values
#non shacl complex 11
set3_min = [1141,532,830,895,448,9027]  # Set 2: min values
set3_max = [10400,41747,33647,33360,33629,35937]  # Set 2: max values
set3_avg = [5522.31,36296.81,23208.89,25316.32,21088.83,18989.11]  # Set 3: average values
# sc
set4_min = [3380,4301,4301,4300,4301,4301]  # Set 4: min values 
set4_max = [10328,5364,5349,5361,5388, 5339]  # Set 4: max values
set4_avg = [  4945.198150 , 4849.308411 , 4837.600467  ,4836.658333 , 4844.430000, 4834.671667     ]  # Set 4: average values



# Create a DataFrame for data
data = {
    'set1_min': set1_min,
    'set1_max': set1_max,
    'set1_avg': set1_avg,
    'set2_min': set2_min,
    'set2_max': set2_max,
    'set2_avg': set2_avg,
    'set3_min': set3_min,
    'set3_max': set3_max,
    'set3_avg': set3_avg,
    'set4_min': set4_min,
    'set4_max': set4_max,
    'set4_avg': set4_avg,
}
df = pd.DataFrame(data, index=x_labels)

# Create a figure for the bar chart
fig, ax = plt.subplots(figsize=(14, 8))

# Bar width and positions
bar_width = 0.15
index = np.arange(len(x_labels))
colors = ['#377eb8', '#4daf4a', '#e41a1c', '#984ea3', '#ff7f00', '#A52A2A', '#a65628', '#f781bf']
hatches = ['|', 'x', '\\', '..', '-', '', '|', '/']  # Crosshatch every second bar
capabilities = ['ShaclSimpleNotOpt', 'ShaclSimpleOpt', 'ShaclComplexNotOpt', 
                'ShaclComplexOpt', 'NoshaclSimple','NoshaclComplex',  'ScSimple', 'ScComplex']
# Bar chart for each set with error bars
bars = [
       ax.bar(index - 1.5 * bar_width, df['set1_avg'], bar_width, color=ColorShaclComplexNotOpt,
              yerr=[df['set1_avg'] - df['set1_min'], df['set1_max'] - df['set1_avg']], capsize=5, edgecolor='black'),

       ax.bar(index - 0.5 * bar_width, df['set2_avg'], bar_width, color=ColorShaclComplexOpt, hatch= hatches[1],
              yerr=[df['set2_avg'] - df['set2_min'], df['set2_max'] - df['set2_avg']], capsize=5, edgecolor='black'),

       ax.bar(index + 0.5 * bar_width, df['set3_avg'], bar_width, color=ColorNoshaclComplex,
              yerr=[df['set3_avg'] - df['set3_min'], df['set3_max'] - df['set3_avg']], capsize=5, edgecolor='black'),

       ax.bar(index + 1.5 * bar_width, df['set4_avg'], bar_width, color=ColorScComplex,
              yerr=[df['set4_avg'] - df['set4_min'], df['set4_max'] - df['set4_avg']], capsize=5, edgecolor='black')
]

# Set labels and title
ax.set_title('Average Latency Complex Validation', fontsize=16,fontweight='bold')
ax.set_xlabel('Transaction Type', fontsize=16, fontweight='bold')
ax.set_ylabel('Latency (ms, log scale)', fontsize=16,fontweight='bold')

# Log scale for the y-axis to accommodate disparity
ax.set_yscale('log')

# Adjust x-tick positions and labels
ax.set_xticks(index)
ax.set_xticklabels(x_labels, fontsize=14,fontweight='bold')
#ax.legend(fontsize=10)

ax.legend([bars[0], bars[1], bars[2], bars[3]],
          [ShaclComplexNotOpt, ShaclComplexOpt, NoshaclComplex, ScComplex],
          fontsize=12, loc='upper left')

# Layout adjustment for better spacing
plt.tight_layout()

plt.savefig("chart4.pdf", format='pdf')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data points for 1 and 4 threads with sample throughput data
capabilities = [ShaclSimpleNotOpt, ShaclSimpleOpt, ShaclComplexNotOpt, ShaclComplexOpt, NoshaclSimple, NoshaclComplex,  ScSimple, ScComplex]
throughput = [4.883716117, 6.573995122, 6.046774649, 5.367076753, 5.134218417, 7.831204141, 0.17, 0.17]

# Colors and hatches - using more print-friendly colors
colors = [ColorShaclSimpleNotOpt, ColorShaclSimpleOpt, ColorShaclComplexNotOpt, ColorShaclComplexOpt, 
          ColorNoshaclSimple, ColorNoshaclComplex, ColorScSimple, ColorScComplex]
hatches = [None, 'x', None, 'x', None, None, None, None]  # Crosshatch every second bar

fig, ax = plt.subplots(figsize=(10, 6))
bars = []

# Create bars with specific hatches and colors
for i in range(len(capabilities)):
    bar = ax.bar(capabilities[i], throughput[i], color=colors[i], hatch=hatches[i], label=capabilities[i])
    bars.append(bar)
    
ax.set_ylabel('Throughput [TPS]', fontsize=16, fontweight='bold')
ax.set_title('Workload = 5 TPS', fontsize=16, fontweight='bold')

# Hide x-axis labels
ax.set_xticks([])  # Removes all x-ticks and labels

# Placing the legend outside of the main plot area on the right
ax.legend(loc='upper right', bbox_to_anchor=(1, 1), fontsize=10)

plt.tight_layout()

plt.savefig("chart5.pdf", format='pdf')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data points for 1 and 4 threads with sample throughput data
capabilities = [ShaclSimpleNotOpt, ShaclSimpleOpt, ShaclComplexNotOpt, ShaclComplexOpt, NoshaclSimple, NoshaclComplex,  ScSimple, ScComplex]
throughput = [3.832625747, 6.020766877, 6.573995122, 2.487744971, 3.665766961, 
              6.103182553, 0.17, 0.17]

# Colors and hatches - using more print-friendly colors
colors = [ColorShaclSimpleNotOpt, ColorShaclSimpleOpt, ColorShaclComplexNotOpt, ColorShaclComplexOpt, 
          ColorNoshaclSimple, ColorNoshaclComplex, ColorScSimple, ColorScComplex]
hatches = [None, 'x', None, 'x', None, None, None, None]  # Crosshatch every second bar

fig, ax = plt.subplots(figsize=(10, 6))
bars = []

# Create bars with specific hatches and colors
for i in range(len(capabilities)):
    bar = ax.bar(capabilities[i], throughput[i], color=colors[i], hatch=hatches[i], label=capabilities[i])
    bars.append(bar)

ax.set_ylabel('Throughput [TPS]', fontsize=16,fontweight='bold')
ax.set_title('Workload = 20 TPS', fontsize=16, fontweight='bold')

# Hide x-axis labels
ax.set_xticks([])  # Removes all x-ticks and labels

# Placing the legend outside of the main plot area on the right
ax.legend(loc='upper right', bbox_to_anchor=(1, 1), fontsize=10)

plt.tight_layout()

plt.savefig("chart6.pdf", format='pdf')

plt.show()
